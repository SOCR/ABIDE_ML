# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel("ABIDE_Complete_2017.xlsx", index_col=0)

# %%
data.head(50)
# Out:
#        subjectIdentifier  Index.1  \
# Index
# 1                  50002      252
# 2                  50003      784
# 3                  50004     1004
# 4                  50005      787
# 5                  50006      478
# 6                  50007     1095
# 7                  50008      825
# 8                  50009      108
# 9                  50010      700
# 10                 50011       74
# 11                 50012      909
# 12                 50013      462
# 13                 50014      815
# 14                 50015      290
# 15                 50016      801
# 16                 50017      546
# 17                 50019       10
# 18                 50020      823
# 19                 50022      657
# 20                 50023      185
# 21                 50024      674
# 22                 50025      887
# 23                 50026      627
# 24                 50027      445
# 25                 50028      778
# 26                 50029       84
# ...

# %%
## Shape of the data frame
data.shape
# Out:
# (1098, 2144)
